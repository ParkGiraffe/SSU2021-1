# %% [markdown]
# **파이썬 기초**

# %%
print('hello')
# Out:
# hello

# %%
tupleD=(1, 2, 3)
type(tupleD)
# Out:
# tuple

# %%
listD=[1, 2, 3]
type(listD)
# Out:
# list

# %%
data = {'apple':10, 'orange': 20, 'lemon': 5, 'lime': 15}
#dictionary type
names = list(data.keys()) #key만 리스트로 가져옴
values = list(data.values()) #value만 리스트로 가져옴
type(values)
type(names)
# Out:
# list

# %% [markdown]
# **배열(Array)**

# %%
import numpy as np
#numpy : array 사용 가능

names = np.array(names) # 리스트였던 names의 자료형을 numpy.ndarray로 바꿈.
values = np.array(values)
names
# Out:
# array(['apple', 'orange', 'lemon', 'lime'], dtype='<U6')

# %%
from google.colab import drive
drive.mount('/content/drive')
